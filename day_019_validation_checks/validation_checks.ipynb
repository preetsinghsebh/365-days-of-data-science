# %% [markdown]
# # Day 19 – Validation & Data Quality Checks
# ## E-Commerce Customer Behavior & Sales Analysis
#
# Objective:
# Validate key results from earlier analysis and document basic data
# quality checks and limitations.

# %%
import pandas as pd

df = pd.read_csv("/content/ecommerce_customer_behavior_dataset.csv")
df.head()
# Out:
#      Order_ID Customer_ID        Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  2023-01-01   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  2023-01-01   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  2023-01-01   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  2023-01-01   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  2023-01-01   40  Female  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# 0       54.28         1             0.00         54.28        Debit Card
# 1      244.90         1             0.00        244.90       Credit Card
# 2       48.15         5             0.00        240.75       Credit Card
# 3      804.06         1           229.28        574.78       Credit Card
# 4      755.61         5             0.00       3778.05  Cash on Delivery
#
# ...

# %%
(df["Total_Amount"] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df["quantity"] <= 0).sum() if "quantity" in df.columns else "quantity column not present"
# Out:
# 'quantity column not present'

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Product_Category"].value_counts().head()
# Out:
# Product_Category
# Sports           667
# Electronics      624
# Fashion          622
# Beauty           621
# Home & Garden    621
# Name: count, dtype: int64

# %%
# Recompute revenue by category (should match earlier)
df.groupby("Product_Category")["Total_Amount"].sum().sort_values(ascending=False).head()
# Out:
# Product_Category
# Electronics      2328806.81
# Home & Garden     908348.86
# Sports            754563.56
# Fashion           375214.93
# Toys              223142.48
# Name: Total_Amount, dtype: float64

# %% [markdown]
# ## Validation Findings & Limitations
#
# - No significant negative or zero values found in total_amount.
# - Duplicate records are minimal after earlier cleaning.
# - Revenue by category aligns with earlier EDA results.
# - Some categories have very few records and may not be reliable.
#
# Limitations:
# - Dataset represents a snapshot in time.
# - Customer identifiers may not reflect unique real-world users.
# - External factors (seasonality, promotions) are not included.
