# %% [markdown]
# # Day 5 – Mini Case Study: Netflix Content Analysis

# %% [markdown]
# # Mini Case Study: Understanding Netflix Content Trends

# %% [markdown]
# ## Problem Statement
#
# The goal of this analysis was to understand the composition and growth of Netflix’s content
# library using publicly available data. The focus was on identifying trends in content type,
# geographic production, and release patterns.

# %% [markdown]
# ## Approach
#
# 1. Cleaned raw Netflix data to handle missing values and inconsistent text.
# 2. Performed exploratory data analysis to identify content trends and distributions.
# 3. Applied SQL-style analytical logic using pandas to answer structured business questions.
# 4. Translated analytical findings into business-oriented insights.

# %% [markdown]
# ## Key Findings
#
# - Netflix’s content library expanded rapidly after 2015.
# - Movies form the majority of titles, but TV shows show steady growth.
# - The United States and India are the top content-producing countries.

# %% [markdown]
# ## Impact & Next Steps
#
# Understanding content trends can help inform decisions around content investment,
# regional expansion, and production strategy.
#
# Further analysis could include:
# - User engagement metrics (if available)
# - Genre-level performance analysis
# - Time-series forecasting of content growth

# %%
import pandas as pd

df = pd.read_csv("/content/netflix_cleaned.csv")
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  year age_rating  \
# 0  This collection includes 12 World War II-era p...  1945      TV-MA
# 1  A mentally unstable Vietnam War veteran works ...  1976          R
# 2  Intent on seeing the Cahulawassee River before...  1972          R
# 3  King Arthur, accompanied by his squire, recrui...  1975         PG
# 4  12 American military prisoners in World War II...  1967    Unknown
#
#    runtime                             genres production_countries  seasons  \
# 0       51                      documentation               ['US']      1.0
# ...
